# %% [markdown]
# class Student derive from Person

# %%
class Student: public Person {
private:
    Course* course;
    double student_GPA;

public:
    Student() {};
    Student(std::string fname, std::string bdate, gender pgender, Course* c, double gpa)
    : person(fname, bdate, pgender), c(), student_GPA(gpa) {};
    
    // copy consrtructor

    // 
    ~Student() {};
}
